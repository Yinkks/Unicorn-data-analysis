# %% [markdown]
# ## PYTHON FOR DATA ANALYTICS PROJECT 2023 – APRIL DAF
#   #### Unicorn Companies

# %% [markdown]
# ###  Private companies with a valuation over $1 billion as of March 2022, including each company's current       valuation,funding, country of origin, industry, select investors, and the years they were founded and became unicorns.

# %% [markdown]
# ## data dictionary :
#
# Field Description
#
# Company : Company name
#
# Valuation: Company valuation in billions (B) of dollars
#
# Date Joined : The date in which the company reached $1 billion in valuation
#
# Industry: Company industry
#
# City: City the company was founded in
#
# Country : Country the company was founded in
#
# Continent: Continent the company was founded in
#
# Year Founded: Year the company was founded
#
# Funding: Total amount raised across all funding rounds in billions (B) or millions (M) of dollars
#
# Select Investors: Top 4 investing firms or individual investors (some have less than 4)

# %%
df = pd.read_csv('Unicorn_Companies.csv')

# %%
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
df.isna().sum()
# Out:
# Company              0
# Valuation            0
# Date Joined          0
# Industry             0
# City                16
# Country              0
# Continent            0
# Year Founded         0
# Funding             12
# Select Investors     1
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Company             object
# Valuation           object
# Date Joined         object
# Industry            object
# City                object
# Country             object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %%
df['Funding'] = df['Funding'].replace('Unknown', 0)

# %%
df['Funding'] = df['Funding'].str.replace('B', '000000000')

# %%
df.head(1)
# Out:
#      Company Valuation Date Joined                 Industry     City Country  \
# 0  Bytedance     $180B  2017-04-07  Artificial intelligence  Beijing   China
#
#   Continent  Year Founded      Funding  \
# 0      Asia          2012  $8000000000
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...

# %%
df['Funding'] = df['Funding'].str.replace('M', '000000')

# %%
df.head(1)
# Out:
#      Company Valuation Date Joined                 Industry     City Country  \
# 0  Bytedance     $180B  2017-04-07  Artificial intelligence  Beijing   China
#
#   Continent  Year Founded      Funding  \
# 0      Asia          2012  $8000000000
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...

# %%
df['Funding'] = df['Funding'].str.replace('$','')
# Out:
# /var/folders/t9/nhlj8m3x0c5bd161kmhfsf800000gn/T/ipykernel_80079/864384738.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Funding'] = df['Funding'].str.replace('$','')

# %%
df.head(1)
# Out:
#      Company Valuation Date Joined                 Industry     City Country  \
# 0  Bytedance     $180B  2017-04-07  Artificial intelligence  Beijing   China
#
#   Continent  Year Founded     Funding  \
# 0      Asia          2012  8000000000
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...

# %%
df['Funding'] = df['Funding'].astype(float)

# %%
print(df.dtypes)
# Out:
# Company              object
# Valuation            object
# Date Joined          object
# Industry             object
# City                 object
# Country              object
# Continent            object
# Year Founded          int64
# Funding             float64
# Select Investors     object
# dtype: object

# %%
df['Valuation'] = df['Valuation'].replace('Unknown', 0)

# %%
df.head(1)
# Out:
#      Company Valuation Date Joined                 Industry     City Country  \
# 0  Bytedance     $180B  2017-04-07  Artificial intelligence  Beijing   China
#
#   Continent  Year Founded       Funding  \
# 0      Asia          2012  8.000000e+09
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...

# %%
df['Valuation'] = df['Valuation'].str.replace('B', '000000000')

# %%
df.head(1)
# Out:
#      Company      Valuation Date Joined                 Industry     City  \
# 0  Bytedance  $180000000000  2017-04-07  Artificial intelligence  Beijing
#
#   Country Continent  Year Founded       Funding  \
# 0   China      Asia          2012  8.000000e+09
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...

# %%
df['Valuation'] = df['Valuation'].str.replace('$','')
# Out:
# /var/folders/t9/nhlj8m3x0c5bd161kmhfsf800000gn/T/ipykernel_80079/3805791577.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Valuation'] = df['Valuation'].str.replace('$','')

# %%
df.head(1)
# Out:
#      Company     Valuation Date Joined                 Industry     City  \
# 0  Bytedance  180000000000  2017-04-07  Artificial intelligence  Beijing
#
#   Country Continent  Year Founded       Funding  \
# 0   China      Asia          2012  8.000000e+09
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...

# %%
df['Valuation'] = df['Valuation'].astype(float)

# %%
print(df.dtypes)
# Out:
# Company              object
# Valuation           float64
# Date Joined          object
# Industry             object
# City                 object
# Country              object
# Continent            object
# Year Founded          int64
# Funding             float64
# Select Investors     object
# dtype: object

# %% [markdown]
# ## insights to draw
# 1. Which unicorn companies have had the biggest return on investment?
# 2. How long does it usually take for a company to become a unicorn? Has it always been this way?
# 3. Which countries have the most unicorns? Are there any cities that appear to be industry hubs?
# 4. Whichinvestorshavefundedthemostunicorns?
# 5. Industries that produce the most unicorns.
# 6. Correlation between 'Funding' and 'Valuation'.
# 7. How 'Valuation' has trended over time (are unicorns being valued more highly in recent years?).
# 8. Distribution of unicorns based on 'Continent'.

# %% [markdown]
# ### INSIGHT 1
# ##### ROI
#
# To determine the return on investment (ROI), i used both the initial investment and the final return. In this case, i approximated it by comparing the 'Funding' (total funding) to the 'Valuation' of each company.
#
# Once I've calculated the ROI for each company, I ranked them to find the ones with the highest ROI.

# %%
df['ROI'] = ((df['Valuation'] - df['Funding']) / df['Funding'])*100
print(df['ROI'])
# Out:
# 0       2150.000000
# 1       1328.571429
# 2       4900.000000
# 3       4650.000000
# 4       1050.000000
#            ...
# 1069     163.852243
# 1070       1.010101
# 1071    1150.000000
# 1072      26.262626
# 1073      61.290323
# Name: ROI, Length: 1074, dtype: float64

# %%
## to sort the companies that had the biggest ROI
df_sorted = df.sort_values(by='ROI', ascending=False)

# %%
top_10 = df_sorted.head(10)
print(top_10[['Company', 'ROI']])
# Out:
#                   Company           ROI
# 189  Otto Bock HealthCare           inf
# 239                Zapier  3.999000e+05
# 61                 Dunamu  1.257606e+04
# 792             Workhuman  1.101111e+04
# 361                  CFGI  1.042632e+04
# 743                Manner  9.900000e+03
# 72        DJI Innovations  7.519048e+03
# 760           GalaxySpace  7.042857e+03
# 5                   Canva  6.893007e+03
# 368            Il Makiage  6.796552e+03

# %%
import matplotlib.pyplot as plt

# Assuming df is your dataframe
top_n = 10  # Number of companies you want to display, e.g., top 10
sorted_df = df.sort_values(by='ROI', ascending=False).head(top_n)

plt.figure(figsize=(12,7))

# Create bar chart
plt.bar(sorted_df['Company'], sorted_df['ROI'], color='RED')

# Title and labels
plt.title('Top Companies by Return on Investment (ROI)')
plt.xlabel('Company')
plt.ylabel('ROI (%)')
plt.xticks(rotation=45)  # Rotate company names for better visibility

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## observation and recommendation for insight 1
#
# ### i . observation:
# Company Zapier  has  shown the most substantial returns on investments among all unicorn companies.
#
# ### ii. recommendation:
# -Investors should diversify their portfolios by investing in those unicorn companies or sectors that have historically shown higher ROIs.
#
# -Companies should focus on R&D(research&development ) and innovative strategies, as the highest ROI companies might have brought something disruptive or novel to the market.
#
# -Before investing, ensure a thorough financial audit of  the company to verify the authenticity of their claimed valuations and funding.

# %% [markdown]
# # INSIGHT 2
#
# ## How long does it usually take for a company to become a unicorn? Has it always been this way?
#
# i calculated the time it took each company to become a unicorn by subtracting the 'Year Founded' from the year part of the 'Date Joined'.
# Once i had  this duration for each company, i calculated the average time.
# To see if it has always been this way, i grouped the companies by their 'Year Founded' or the year they became unicorns (from 'Date Joined') to see if the average time to become a unicorn has changed over the years.

# %%
df['Year Joined'] = pd.to_datetime(df['Date Joined']).dt.year

# %%
df['Time to Unicorn'] = df['Year Joined'] - df['Year Founded']

# %%
average_time = df['Time to Unicorn'].mean()
print(f"Average time to become a unicorn: {average_time} years")
# Out:
# Average time to become a unicorn: 7.000931098696462 years

# %%
grouped = df.groupby('Year Founded')['Time to Unicorn'].mean()

print(grouped)
# Out:
# Year Founded
# 1919    98.000000
# 1979    37.000000
# 1984    37.000000
# 1990    27.000000
# 1991    27.000000
# 1992    25.000000
# 1993    28.000000
# 1994    21.500000
# 1995    21.500000
# 1996    25.000000
# 1997    20.000000
# 1998    19.800000
# 1999    19.375000
# 2000    19.272727
# 2001    16.666667
# 2002    13.250000
# 2003    15.500000
# 2004    15.250000
# 2005    13.571429
# 2006    12.933333
# 2007    11.500000
# 2008    11.222222
# 2009    10.147059
# 2010     8.950000
# 2011     8.353659
# 2012     7.463158
# 2013     6.712644
# 2014     6.018349
# 2015     5.200000
# 2016     4.463636
# 2017     3.810811
# 2018     3.114754
# 2019     2.177778
# 2020     1.080000
# 2021     0.000000
# Name: Time to Unicorn, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
grouped.plot()
plt.ylabel('Average Time to Unicorn (years)')
plt.xlabel('Year Founded')
plt.title('Trend of Time to Become a Unicorn Over the Years')
plt.show()

# %% [markdown]
# ## observation and recommendation for insight 2
#
# ### i . observation:
# On average, it takes 7  years for companies to achieve unicorn status.
# n the past decade, companies have reached unicorn status quicker compared to earlier years, indicating a more aggressive investment environment or quicker scaling strategies..
# ### ii. recommendation:
# Early-Stage Investment: Investors should consider early-stage investments as startups are achieving unicorn status faster than before.
#
# Adopt Modern Business Models: For startups, adopting newer, agile business models and leveraging modern tech might help achieve unicorn status faster.
#
# Market Analysis: Before any investment, a deep market trend analysis should be done to understand the factors that have accelerated unicorn status in recent years.

# %% [markdown]
# # insight 3
#
# ## Which countries have the most unicorns? Are there any cities that appear to be industry hubs?
#
# to determine which countries have the most unicorns and identify potential city hubs for unicorn companies, I used the groupby and count functions

# %%
# counting country by unicorn 
country_counts = df.groupby('Country')['Company'].count().sort_values(ascending=False)
print(country_counts)
# Out:
# Country
# United States           562
# China                   173
# India                    65
# United Kingdom           43
# Germany                  26
# France                   24
# Israel                   20
# Canada                   19
# Brazil                   16
# South Korea              12
# Singapore                12
# Australia                 8
# Netherlands               6
# Mexico                    6
# Hong Kong                 6
# Sweden                    6
# Indonesia                 6
# Japan                     5
# Ireland                   5
# Switzerland               5
# Norway                    4
# Finland                   4
# Spain                     3
# United Arab Emirates      3
# Turkey                    3
# Belgium                   3
# Thailand                  2
# Chile                     2
# South Africa              2
# Colombia                  2
# Estonia                   2
# Denmark                   2
# Philippines               2
# ...

# %%
#counting unicorns by city 
city_counts = df.groupby('City')['Company'].count().sort_values(ascending=False)
print(city_counts)
# Out:
# City
# San Francisco       152
# New York            103
# Beijing              63
# Shanghai             44
# London               34
#                    ...
# Irving                1
# Islandia              1
# Jacksonville          1
# Jaipur                1
# Lerma de Villada      1
# Name: Company, Length: 256, dtype: int64

# %%
# plotting for country by unicorns
country_counts.head(10).plot(kind='bar', color='blue', figsize=(10,6))
plt.title('Top 10 Countries with the Most Unicorns')
plt.ylabel('Number of Unicorns')
plt.xlabel('Country')
plt.show()

# %%
#plotting for cities by unicorn
city_counts.head(10).plot(kind='bar', color='green', figsize=(10,6))
plt.title('Top 10 Cities with the Most Unicorns')
plt.ylabel('Number of Unicorns')
plt.xlabel('City')
plt.show()

# %% [markdown]
# ## observation and recommendation for insight 3
#
# ### i . observation:
# United states  has the most unicorn companies, with cities San Franscisco andNew york  being notable hubs for these high-valued startups.
#
# Cities like Beijing , even if they are not in the leading countries, have emerged as significant startup hubs.
# ### ii. recommendation:
# Geographical Diversification: Investors should diversify their portfolios geographically, not just focusing on traditional hubs but also upcoming cities.
#
# Relocation Consideration: Startups might consider relocating or opening branches in these hub cities to get better access to resources, talent, and funding opportunities.
#
# Government Initiatives: Governments of countries/cities lagging behind can introduce startup-friendly policies and create conducive ecosystems for startups to thrive.

# %% [markdown]
# ## insight 4
#
# ## Which investors have funded the most unicorns?
#
# 1. I'll  split the 'Select Investors' column into a list of individual investors for each company.
#  2. count how often each investor appears in the 'Investors' lists. One way to do this is to flatten the lists and then use a Counter to count occurrences.
#  3. Sort the Investors by Count
#  4. visualize

# %%
df['Investors'] = df['Select Investors'].str.split(',')

# %%
from collections import Counter

all_investors = [investor.strip() for sublist in df['Investors'].dropna() for investor in sublist]
investor_counts = Counter(all_investors)

# %%
sorted_investors = sorted(investor_counts.items(), key=lambda x: x[1], reverse=True)

# %%
# Display top 10 investors
for investor, count in sorted_investors[:10]:
    print(f"{investor}: {count} unicorns")
# Out:
# Accel: 60 unicorns
# Tiger Global Management: 53 unicorns
# Andreessen Horowitz: 53 unicorns
# Sequoia Capital China: 48 unicorns
# Sequoia Capital: 47 unicorns
# Insight Partners: 47 unicorns
# SoftBank Group: 34 unicorns
# General Catalyst: 34 unicorns
# Lightspeed Venture Partners: 34 unicorns
# Index Ventures: 32 unicorns

# %%
import matplotlib.pyplot as plt

# Extract top 10 investors and their counts
top_investors = [x[0] for x in sorted_investors[:10]]
top_counts = [x[1] for x in sorted_investors[:10]]

# Plotting
plt.figure(figsize=(12, 7))
plt.barh(top_investors, top_counts, color='purple')
plt.xlabel('Number of Unicorns Funded')
plt.title('Top 10 Investors Funding the Most Unicorns')
plt.gca().invert_yaxis()  # To display the top investor at the top
plt.show()

# %% [markdown]
# ## observation and recommendation for insight 4
#
# ### i . observation:
# Investors Accel, Tiger Global Management, and Adreessen Horowitz  are the top players in funding unicorn companies, having a diverse portfolio across multiple sectors.
#
# These investors often engage early in a startup's lifecycle, contributing not just funds but also mentorship and strategic guidance.
#
# ### ii. recommendation:
# Strategic Partnerships: Startups should aim to secure investments from these top players as it might provide them with better networking opportunities, mentorship, and credibility in the market.
#
# Diverse Portfolio: Investors can look into diversifying their portfolios across various sectors, as seen with the top investors.
#
# Collaborative Ventures: Smaller investors might consider forming consortiums or collaborative ventures to invest in high-potential startups, emulating the success model of top investors.

# %% [markdown]
# ## INSIGHT 5
#
# ## Industries that produce the most unicorns.

# %%
industry_counts = df['Industry'].value_counts()
print(industry_counts)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.barplot(y=industry_counts.index, x=industry_counts.values, palette="viridis")
plt.xlabel('Number of Unicorns')
plt.ylabel('Industry')
plt.title('Number of Unicorns by Industry')
plt.show()

# %% [markdown]
# ## observation and recommendation for insight 5
#
# ### i . observation:
# -Some industries might consistently produce more unicorn companies. This can indicate industries that are currently undergoing rapid innovation or transformation. For instance, if the tech or fintech sectors are producing many unicorns, it suggests strong technological disruption in these sectors.
#
# -If an industry suddenly starts producing more unicorns, it might be an indicator of a new trend or a transformative change within that sector.
#
# -Stable Industries: Industries that have a consistent, but not necessarily high, number of unicorns over time might represent stable, mature markets that still offer steady opportunities for growth.
#
# -Lagging Industries: Some sectors may produce very few or no unicorns, indicating possible stagnation, higher entry barriers, or fewer innovation opportunities in those fields.
# ### ii. recommendation:
# Targeted Investment: For investors, understanding which industries are producing the most unicorns can help in directing their investments more strategically. Investing in dominant or emerging industries might offer higher returns.
#
# Diversification: Businesses and investors might consider diversifying their portfolios or operations into industries showing a consistent rise in unicorn companies, as it can be a sign of long-term growth and sustainability.
#
# Innovation Boost: For industries lagging in unicorn formation, there might be a need for increased innovation. Companies in these sectors can consider investing more in R&D, partnering with startups, or exploring new business models.
#
# Government and Policy Intervention: In industries where unicorn formation is low, governments can play a role by revising regulations, offering tax incentives, or funding research and innovation to make the environment more conducive for startups.
#
# Collaborative Ventures: Companies in dominant unicorn-producing industries can seek collaborative ventures or acquisitions in emerging industries, leveraging their resources and expertise to tap into new markets and trends.
#
# Trend Analysis: Regularly analyzing which industries are producing unicorns can help businesses and investors stay ahead of market trends. It's essential to be proactive and not just reactive to industry shifts.
#
# By understanding the industries that produce the most unicorns, stakeholders can align their strategies with current market trends, capitalize on emerging opportunities, and make informed decisions to navigate challenges in less active sectors.

# %% [markdown]
# ## insight 6
#
# ## Correlation between 'Funding' and 'Valuation'.

# %%
correlation = df['Funding'].corr(df['Valuation'])
print(f"Correlation between Funding and Valuation: {correlation:.2f}")
# Out:
# Correlation between Funding and Valuation: 0.60

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Funding'], y=df['Valuation'])
plt.title('Scatter Plot between Funding and Valuation')
plt.xlabel('Funding')
plt.ylabel('Valuation')
plt.show()

# %% [markdown]
# ## observation and recommendation for insight 6
#
# ### i . observation: because the correlation value is close to 1 and the scatter plot shows an upward trend, : "There's a strong positive relationship between funding received and company valuation."
#
# ### ii. recommendation: companies seeking higher valuations should prioritize effective fundraising strategies

# %% [markdown]
# ## INSIGHT 7
# ## How 'Valuation' has trended over time (are unicorns being valued more highly in recent years?).
#
# To understand how 'Valuation' has trended over time, I will analyze the valuation based on the 'Date Joined' column (the date when companies reached $1 billion valuation). Here's a step-by-step process:
#
# Data Preparation:
#
# Ensured there are no missing values in the 'Valuation' and 'Date Joined' columns.
# Converted  the 'Date Joined' column to a datetime .
#
# Grouping Data by Year:
#
# To see the trend over time, i grouped the data by year.

# %%
import pandas as pd
df['Date Joined'] = pd.to_datetime(df['Date Joined'])

# %%
print(df['Date Joined'].dtypes)
# Out:
# datetime64[ns]

# %%
# Extracting year from 'Date Joined' and creating a new column 'Year Joined'
df['Year Joined'] = df['Date Joined'].dt.year

# Calculating the average valuation for each year
yearly_valuation = df.groupby('Year Joined')['Valuation'].mean().reset_index()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(yearly_valuation['Year Joined'], yearly_valuation['Valuation'], marker='o', linestyle='-')
plt.title('Trend of Average Valuation Over Time')
plt.xlabel('Year')
plt.ylabel('Average Valuation (in billions)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## observation and recommendation for insight 7
#
# ### i . observation:the line went up in between 2008 , reached an high peak by  2012 then started trending downward , it suggests that the that unicorns are being valued more lower  in recent years.
#
# ### ii. recommendation: "The decreasing trend might be indicative of market saturation, changing investor sentiment, or a more cautious approach to valuing unicorns. Stakeholders need to understand the underlying reasons and strategize accordingly, taking into consideration the processes that they adopted during the peak years."

# %% [markdown]
# ## INSIGHT 8
#
# ## Distribution of unicorns based on 'Continent':
# First,i  got the count of unicorns for each continent. i achieved  this using the value_counts() method.
# Then, i plotted the resulting Series.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Count unicorns for each continent
unicorn_counts = df['Continent'].value_counts()

# %%
# Plot the counts
unicorn_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of Unicorns by Continent')
plt.xlabel('Continent')
plt.ylabel('Number of Unicorns')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## observation and recommendation for insight 8
#
# ### i . observation:
# -North America has the highest number of unicorn companies, indicating that it's a major hub for startups with high growth potential.
# -Africa  in contrast, has a significantly lower number of unicorns, suggesting either untapped potential or challenges in scaling startups in that region.
# -Asia: shows moderate numbers, suggesting a balanced ecosystem for startups.
#
# ### ii. recommendation:
# Investment Focus: Investors seeking to diversify their portfolio might consider increasing their attention towards emerging markets in Africa  which might have untapped potential or less competition.
#
# Resource Allocation: Entities that support startup growth, such as venture capital firms, accelerators, and incubators, might see potential in scaling operations in North America  due to the evident success rate of unicorns there.
#
# Regulatory Reforms: Governments and regulatory bodies in continents with fewer unicorns could study the startup-friendly policies of North America and consider implementing similar reforms to foster a conducive environment for startups.
#
# Entrepreneurial Ecosystem: Entrepreneurs and startup founders in regions with fewer unicorns might consider networking and building relationships in hubs in North America, which could provide them with mentorship, resources, and better fundraising opportunities.
